# %% [markdown]
# # imports & functions

# %%
import os
import shutil
import pandas as pd

def list_all_datapaths(data_path):
    data_paths = []
    for file in os.listdir(data_path):
        if 'EJT' in file[0:5] or 'revision' in data_path:
            for file_ in os.listdir(data_path+file):
                if 'record' in file_:
                    data_paths += [data_path+file+'\\'+file_]
            
    return data_paths

def copy_files(source_file, dest_file):
    if not os.path.exists(dest_file):
        shutil.copy(source_file, dest_file)
        print(f"Copied {source_file} to {dest_file}")
    else:
        print(f"File already exists at {dest_file}, not copied.")

# %% [markdown]
# # main

# %%
# get current working directory
current_dir = os.getcwd()
recordings_date_data = pd.read_csv(os.path.join(current_dir,'consecutive_data.csv'))

out_path = r"Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\"

# %%
for i in range(len(recordings_date_data)):

    current_row = recordings_date_data.loc[recordings_date_data.index[i]]
    
    # Create destination directory if it doesn't exist
    destination_folder1 = os.path.join(out_path,current_row['mouse_id'],'day1_' + current_row['behaviour 1'].replace('/','-'))
    os.makedirs(destination_folder1, exist_ok=True)
    
    if 'EJT' in current_row['mouse_id']:
        organised_path = r"Z:\projects\sequence_squad\organised_data\animals\\"
        row_mouse = current_row['mouse_id'].split('T')[-1]
    else:
        organised_path = r"Z:\projects\sequence_squad\revision_data\organised_data\animals\\"
        row_mouse = current_row['mouse_id'].lower()
        if 'ap5' in row_mouse:
            row_mouse = row_mouse.replace('r','R')

    ##############################
    # if not 'ap5' in row_mouse:
    #     continue  # skip if not AP5 mouse
    ##############################

    # load in the first days data:
    
    # list out all possible datapaths
    data_paths = list_all_datapaths(organised_path) 

    for path in data_paths:
        if 'EJT' in path:
            a = path.split('\\')[-2].split('_')[0][3::]
        else:
            a = path.split('\\')[-2].split('_')[0]
        b = path.split('\\')[-2][-1]
        c = path.split('\\')[-1].split('_')[0].split('g')[-1]
        current_mouse = '_'.join([a,b,c])

        if current_mouse != row_mouse:
            continue
        print('-------------------------------')
        print(f"behav 1 =  {current_row['mouse_id']} {current_row['behaviour 1']}")
    
        for stage in os.listdir(os.path.join(path,'behav_sync')):
            if 'task' in stage:
                behav1_path = os.path.join(path,'behav_sync',stage)
                # Copy file only if it doesn't already exist
                copy_files(os.path.join(behav1_path,'Behav_Ephys_Camera_Sync.csv'), os.path.join(destination_folder1,'Behav_Ephys_Camera_Sync.csv'))
                
        # get tracking data for behaviour 1
        video_path = os.path.join(path,'video','tracking') + r'\\'
        if os.path.isdir(video_path) == False:
            print('Cant find video:', video_path)

        if 'EJT' in current_row['mouse_id']:
            for stage in os.listdir(video_path):
                if 'task' in stage: 
                    tracking_path = video_path + stage + '\\'
        else:
            tracking_path = video_path 
                    
        for track_file in os.listdir(tracking_path):
            if 'back' in track_file and 'task' in track_file and '.h5' in track_file:
                print(f'Found task tracking file {track_file}')
                copy_files(os.path.join(tracking_path,track_file), os.path.join(destination_folder1,track_file))
            if 'back' in track_file and 'port' in track_file and '.h5' in track_file:
                print(f'Found port tracking file {track_file}')
                copy_files(os.path.join(tracking_path,track_file), os.path.join(destination_folder1,track_file))
            if 'BACK' in track_file and not 'PORT' in track_file and '.h5' in track_file:
                print(f'Found task tracking file {track_file}')
                copy_files(os.path.join(tracking_path,track_file), os.path.join(destination_folder1,track_file))
            if 'BACK' in track_file and 'PORT' in track_file and '.h5' in track_file:
                print(f'Found port tracking file {track_file}')
                copy_files(os.path.join(tracking_path,track_file), os.path.join(destination_folder1,track_file))
    
    
    ################## try to data for behaviour 2
    
    # Create destination directory if it doesn't exist
    destination_folder2 = os.path.join(out_path,current_row['mouse_id'],'day2_' + current_row['behaviour 2'].replace('/','-'))
    os.makedirs(destination_folder2, exist_ok=True)
    
    # search in each possible location for the data
    File_found = False
    copied = False
    # 1. organised data structures
    for path_ in data_paths:
        path_date = path_.split('_')[-1].replace('-', '/')
        if current_row['behaviour 2'] == path_date:
            path_mouse_implant_code = row_mouse.split('_')[0] + '_implant' + row_mouse.split('_')[1]
            if path_mouse_implant_code in path_:
                File_found = True            
        if not File_found:
            continue
        # reset the file found flag
        File_found = False
        print('-------------------------------')
        print(f"behav 2 =  {current_row['mouse_id']} {current_row['behaviour 2']}")
        print(f"path = {path_}")

        # copy over the behav data: 
        for stage in os.listdir(os.path.join(path_,'behav_sync')):
            if 'task' in stage:
                behav2_path = os.path.join(path_,'behav_sync',stage)
                # Copy file only if it doesn't already exist
                copy_files(os.path.join(behav2_path,'Behav_Ephys_Camera_Sync.csv'), os.path.join(destination_folder2,'Behav_Ephys_Camera_Sync.csv')) 
                
        ## find camera data for behaviour 2
        video_path = os.path.join(path_,'video','tracking') + r'\\'
        if os.path.isdir(video_path) == False:
            print('Cant find video:', video_path)

        if 'EJT' in current_row['mouse_id']:
            for stage in os.listdir(video_path):
                if 'task' in stage: 
                    tracking_path = video_path + stage + '\\'
        else:
            tracking_path = video_path
                    
        for track_file in os.listdir(tracking_path):
            if 'back' in track_file and 'task' in track_file and '.h5' in track_file:
                print(f'Found task tracking file {track_file}')
                copy_files(os.path.join(tracking_path,track_file), os.path.join(destination_folder2,track_file))
            if 'back' in track_file and 'port' in track_file and '.h5' in track_file:
                print(f'Found port tracking file {track_file}')
                copy_files(os.path.join(tracking_path,track_file), os.path.join(destination_folder2,track_file))
            if 'BACK' in track_file and not 'PORT' in track_file and '.h5' in track_file:
                print(f'Found task tracking file {track_file}')
                copy_files(os.path.join(tracking_path,track_file), os.path.join(destination_folder2,track_file))
            if 'BACK' in track_file and 'PORT' in track_file and '.h5' in track_file:
                print(f'Found port tracking file {track_file}')
                copy_files(os.path.join(tracking_path,track_file), os.path.join(destination_folder2,track_file))
                # processes these one by one and put them in a folder
        copied = True
                    
                    
    if not copied:
        print('NOPE! bpod data (and camera data?) needs to be processed!')
# Out:
# -------------------------------
# behav 1 =  EJT136_1_3 11/11/2021
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT136_1_3\day1_11-11-2021\Behav_Ephys_Camera_Sync.csv, not copied.
# Found port tracking file back_2021-11-11T15_07_18DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT136_1_3\day1_11-11-2021\back_2021-11-11T15_07_18DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5, not copied.
# Found task tracking file back_2021-11-11T15_07_18DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT136_1_3\day1_11-11-2021\back_2021-11-11T15_07_18DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5, not copied.
# -------------------------------
# behav 2 =  EJT136_1_3 12/11/2021
# path = Z:\projects\sequence_squad\organised_data\animals\\EJT136_implant1\recording4_12-11-2021
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT136_1_3\day2_12-11-2021\Behav_Ephys_Camera_Sync.csv, not copied.
# Found port tracking file back_2021-11-12T16_25_12DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT136_1_3\day2_12-11-2021\back_2021-11-12T16_25_12DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5, not copied.
# Found task tracking file back_2021-11-12T16_25_12DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT136_1_3\day2_12-11-2021\back_2021-11-12T16_25_12DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5, not copied.
# -------------------------------
# behav 1 =  EJT136_1_4 12/11/2021
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT136_1_4\day1_12-11-2021\Behav_Ephys_Camera_Sync.csv, not copied.
# Found port tracking file back_2021-11-12T16_25_12DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT136_1_4\day1_12-11-2021\back_2021-11-12T16_25_12DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5, not copied.
# Found task tracking file back_2021-11-12T16_25_12DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT136_1_4\day1_12-11-2021\back_2021-11-12T16_25_12DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5, not copied.
# NOPE! bpod data (and camera data?) needs to be processed!
# -------------------------------
# behav 1 =  EJT149_1_1 16/11/2021
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT149_1_1\day1_16-11-2021\Behav_Ephys_Camera_Sync.csv, not copied.
# Found port tracking file back_2021-11-16T12_58_48DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT149_1_1\day1_16-11-2021\back_2021-11-16T12_58_48DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5, not copied.
# Found task tracking file back_2021-11-16T12_58_48DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT149_1_1\day1_16-11-2021\back_2021-11-16T12_58_48DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5, not copied.
# -------------------------------
# behav 2 =  EJT149_1_1 17/11/2021
# path = Z:\projects\sequence_squad\organised_data\animals\\EJT149_implant1\recording2_17-11-2021
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT149_1_1\day2_17-11-2021\Behav_Ephys_Camera_Sync.csv, not copied.
# Found port tracking file back_2021-11-17T14_46_41DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT149_1_1\day2_17-11-2021\back_2021-11-17T14_46_41DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5, not copied.
# Found task tracking file back_2021-11-17T14_46_41DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT149_1_1\day2_17-11-2021\back_2021-11-17T14_46_41DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5, not copied.
# -------------------------------
# behav 1 =  EJT178_1_6 29/03/2022
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_1_6\day1_29-03-2022\Behav_Ephys_Camera_Sync.csv, not copied.
# Found port tracking file back_2022-03-29T13_58_26DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_1_6\day1_29-03-2022\back_2022-03-29T13_58_26DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5, not copied.
# Found task tracking file back_2022-03-29T13_58_26DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_1_6\day1_29-03-2022\back_2022-03-29T13_58_26DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5, not copied.
# -------------------------------
# behav 2 =  EJT178_1_6 30/03/2022
# path = Z:\projects\sequence_squad\organised_data\animals\\EJT178_implant1\recording7_30-03-2022
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_1_6\day2_30-03-2022\Behav_Ephys_Camera_Sync.csv, not copied.
# Found port tracking file back_2022-03-30T15_02_32DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_1_6\day2_30-03-2022\back_2022-03-30T15_02_32DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5, not copied.
# Found task tracking file back_2022-03-30T15_02_32DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_1_6\day2_30-03-2022\back_2022-03-30T15_02_32DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5, not copied.
# -------------------------------
# behav 1 =  EJT178_1_7 30/03/2022
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_1_7\day1_30-03-2022\Behav_Ephys_Camera_Sync.csv, not copied.
# Found port tracking file back_2022-03-30T15_02_32DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_1_7\day1_30-03-2022\back_2022-03-30T15_02_32DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5, not copied.
# Found task tracking file back_2022-03-30T15_02_32DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_1_7\day1_30-03-2022\back_2022-03-30T15_02_32DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5, not copied.
# -------------------------------
# behav 2 =  EJT178_1_7 31/03/2022
# path = Z:\projects\sequence_squad\organised_data\animals\\EJT178_implant1\recording8_31-03-2022
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_1_7\day2_31-03-2022\Behav_Ephys_Camera_Sync.csv, not copied.
# Found port tracking file back_2022-03-31T14_26_11DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_1_7\day2_31-03-2022\back_2022-03-31T14_26_11DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5, not copied.
# Found task tracking file back_2022-03-31T14_26_11DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_1_7\day2_31-03-2022\back_2022-03-31T14_26_11DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5, not copied.
# -------------------------------
# behav 1 =  EJT178_1_8 31/03/2022
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_1_8\day1_31-03-2022\Behav_Ephys_Camera_Sync.csv, not copied.
# Found port tracking file back_2022-03-31T14_26_11DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_1_8\day1_31-03-2022\back_2022-03-31T14_26_11DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5, not copied.
# Found task tracking file back_2022-03-31T14_26_11DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_1_8\day1_31-03-2022\back_2022-03-31T14_26_11DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5, not copied.
# -------------------------------
# behav 2 =  EJT178_1_8 01/04/2022
# path = Z:\projects\sequence_squad\organised_data\animals\\EJT178_implant1\recording9_01-04-2022
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_1_8\day2_01-04-2022\Behav_Ephys_Camera_Sync.csv, not copied.
# Found port tracking file back_2022-04-01T17_02_51DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_1_8\day2_01-04-2022\back_2022-04-01T17_02_51DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5, not copied.
# Found task tracking file back_2022-04-01T17_02_51DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_1_8\day2_01-04-2022\back_2022-04-01T17_02_51DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5, not copied.
# -------------------------------
# behav 1 =  EJT178_2_1 04/04/2022
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_2_1\day1_04-04-2022\Behav_Ephys_Camera_Sync.csv, not copied.
# Found port tracking file back_2022-04-04T14_20_02DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_2_1\day1_04-04-2022\back_2022-04-04T14_20_02DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5, not copied.
# Found task tracking file back_2022-04-04T14_20_02DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_2_1\day1_04-04-2022\back_2022-04-04T14_20_02DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5, not copied.
# -------------------------------
# behav 2 =  EJT178_2_1 05/04/2022
# path = Z:\projects\sequence_squad\organised_data\animals\\EJT178_implant2\recording2_05-04-2022
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_2_1\day2_05-04-2022\Behav_Ephys_Camera_Sync.csv, not copied.
# Found port tracking file back_2022-04-05T14_12_57DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_2_1\day2_05-04-2022\back_2022-04-05T14_12_57DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5, not copied.
# Found task tracking file back_2022-04-05T14_12_57DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_2_1\day2_05-04-2022\back_2022-04-05T14_12_57DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5, not copied.
# -------------------------------
# behav 1 =  EJT178_2_2 05/04/2022
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_2_2\day1_05-04-2022\Behav_Ephys_Camera_Sync.csv, not copied.
# Found port tracking file back_2022-04-05T14_12_57DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_2_2\day1_05-04-2022\back_2022-04-05T14_12_57DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5, not copied.
# Found task tracking file back_2022-04-05T14_12_57DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_2_2\day1_05-04-2022\back_2022-04-05T14_12_57DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5, not copied.
# -------------------------------
# behav 2 =  EJT178_2_2 06/04/2022
# path = Z:\projects\sequence_squad\organised_data\animals\\EJT178_implant2\recording3_06-04-2022
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_2_2\day2_06-04-2022\Behav_Ephys_Camera_Sync.csv, not copied.
# Found port tracking file back_2022-04-06T13_00_11DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_2_2\day2_06-04-2022\back_2022-04-06T13_00_11DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5, not copied.
# Found task tracking file back_2022-04-06T13_00_11DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_2_2\day2_06-04-2022\back_2022-04-06T13_00_11DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5, not copied.
# -------------------------------
# behav 1 =  EJT178_2_3 06/04/2022
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_2_3\day1_06-04-2022\Behav_Ephys_Camera_Sync.csv, not copied.
# Found port tracking file back_2022-04-06T13_00_11DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_2_3\day1_06-04-2022\back_2022-04-06T13_00_11DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5, not copied.
# Found task tracking file back_2022-04-06T13_00_11DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_2_3\day1_06-04-2022\back_2022-04-06T13_00_11DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5, not copied.
# -------------------------------
# behav 2 =  EJT178_2_3 07/04/2022
# path = Z:\projects\sequence_squad\organised_data\animals\\EJT178_implant2\recording4_07-04-2022
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_2_3\day2_07-04-2022\Behav_Ephys_Camera_Sync.csv, not copied.
# Found port tracking file back_2022-04-07T14_04_10DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_2_3\day2_07-04-2022\back_2022-04-07T14_04_10DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5, not copied.
# Found task tracking file back_2022-04-07T14_04_10DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT178_2_3\day2_07-04-2022\back_2022-04-07T14_04_10DLC_resnet50_task-tracking_backviewApr6shuffle1_800000.h5, not copied.
# -------------------------------
# behav 1 =  EJT269_1_2 15/05/2023
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT269_1_2\day1_15-05-2023\Behav_Ephys_Camera_Sync.csv, not copied.
# Found port tracking file back_2023-05-15T15_02_57DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT269_1_2\day1_15-05-2023\back_2023-05-15T15_02_57DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5, not copied.
# Found task tracking file back_2023-05-15T15_02_57DLC_resnet50_Yellow-floor-task-tracking-backviewApr9shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT269_1_2\day1_15-05-2023\back_2023-05-15T15_02_57DLC_resnet50_Yellow-floor-task-tracking-backviewApr9shuffle1_800000.h5, not copied.
# -------------------------------
# behav 2 =  EJT269_1_2 16/05/2023
# path = Z:\projects\sequence_squad\organised_data\animals\\EJT269_implant1\recording3_16-05-2023
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT269_1_2\day2_16-05-2023\Behav_Ephys_Camera_Sync.csv, not copied.
# Found port tracking file back_2023-05-16T18_06_14DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT269_1_2\day2_16-05-2023\back_2023-05-16T18_06_14DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5, not copied.
# Found task tracking file back_2023-05-16T18_06_14DLC_resnet50_Yellow-floor-task-tracking-backviewApr9shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT269_1_2\day2_16-05-2023\back_2023-05-16T18_06_14DLC_resnet50_Yellow-floor-task-tracking-backviewApr9shuffle1_800000.h5, not copied.
# -------------------------------
# behav 1 =  EJT269_1_4 18/05/2023
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT269_1_4\day1_18-05-2023\Behav_Ephys_Camera_Sync.csv, not copied.
# Found port tracking file back_2023-05-18T18_02_24DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT269_1_4\day1_18-05-2023\back_2023-05-18T18_02_24DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5, not copied.
# Found task tracking file back_2023-05-18T18_02_24DLC_resnet50_Yellow-floor-task-tracking-backviewApr9shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT269_1_4\day1_18-05-2023\back_2023-05-18T18_02_24DLC_resnet50_Yellow-floor-task-tracking-backviewApr9shuffle1_800000.h5, not copied.
# -------------------------------
# behav 2 =  EJT269_1_4 19/05/2023
# path = Z:\projects\sequence_squad\organised_data\animals\\EJT269_implant1\recording5_19-05-2023
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT269_1_4\day2_19-05-2023\Behav_Ephys_Camera_Sync.csv, not copied.
# Found port tracking file back_2023-05-19T12_47_08DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT269_1_4\day2_19-05-2023\back_2023-05-19T12_47_08DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5, not copied.
# Found task tracking file back_2023-05-19T12_47_08DLC_resnet50_Yellow-floor-task-tracking-backviewApr9shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT269_1_4\day2_19-05-2023\back_2023-05-19T12_47_08DLC_resnet50_Yellow-floor-task-tracking-backviewApr9shuffle1_800000.h5, not copied.
# -------------------------------
# behav 1 =  EJT270_1_6 19/05/2023
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT270_1_6\day1_19-05-2023\Behav_Ephys_Camera_Sync.csv, not copied.
# Found port tracking file back_2023-05-19T16_47_03DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT270_1_6\day1_19-05-2023\back_2023-05-19T16_47_03DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5, not copied.
# Found task tracking file back_2023-05-19T16_47_03DLC_resnet50_Yellow-floor-task-tracking-backviewApr9shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT270_1_6\day1_19-05-2023\back_2023-05-19T16_47_03DLC_resnet50_Yellow-floor-task-tracking-backviewApr9shuffle1_800000.h5, not copied.
# -------------------------------
# behav 2 =  EJT270_1_6 20/05/2023
# path = Z:\projects\sequence_squad\organised_data\animals\\EJT270_implant1\recording7_20-05-2023
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT270_1_6\day2_20-05-2023\Behav_Ephys_Camera_Sync.csv, not copied.
# Found port tracking file back_2023-05-20T17_11_30DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT270_1_6\day2_20-05-2023\back_2023-05-20T17_11_30DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5, not copied.
# Found task tracking file back_2023-05-20T17_11_30DLC_resnet50_Yellow-floor-task-tracking-backviewApr9shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT270_1_6\day2_20-05-2023\back_2023-05-20T17_11_30DLC_resnet50_Yellow-floor-task-tracking-backviewApr9shuffle1_800000.h5, not copied.
# -------------------------------
# behav 1 =  SEQ006_1_8 25/11/2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_8\day1_25-11-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found task tracking file BACK_CAM_seq006_25-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_8\day1_25-11-2024\BACK_CAM_seq006_25-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5, not copied.
# Found port tracking file BACK_CAM_seq006_25-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_8\day1_25-11-2024\BACK_CAM_seq006_25-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5, not copied.
# -------------------------------
# behav 2 =  SEQ006_1_8 26/11/2024
# path = Z:\projects\sequence_squad\revision_data\organised_data\animals\\seq006_implant1\recording9_26-11-2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_8\day2_26-11-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found task tracking file BACK_CAM_seq006_26-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_8\day2_26-11-2024\BACK_CAM_seq006_26-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5, not copied.
# Found port tracking file BACK_CAM_seq006_26-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_8\day2_26-11-2024\BACK_CAM_seq006_26-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5, not copied.
# -------------------------------
# behav 1 =  SEQ006_1_9 26/11/2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_9\day1_26-11-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found task tracking file BACK_CAM_seq006_26-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_9\day1_26-11-2024\BACK_CAM_seq006_26-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5, not copied.
# Found port tracking file BACK_CAM_seq006_26-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_9\day1_26-11-2024\BACK_CAM_seq006_26-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5, not copied.
# -------------------------------
# behav 2 =  SEQ006_1_9 27/11/2024
# path = Z:\projects\sequence_squad\revision_data\organised_data\animals\\seq006_implant1\recording10_27-11-2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_9\day2_27-11-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found task tracking file BACK_CAM_seq006_27-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_9\day2_27-11-2024\BACK_CAM_seq006_27-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5, not copied.
# Found port tracking file BACK_CAM_seq006_27-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_9\day2_27-11-2024\BACK_CAM_seq006_27-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5, not copied.
# -------------------------------
# behav 1 =  SEQ006_1_10 27/11/2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_10\day1_27-11-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found task tracking file BACK_CAM_seq006_27-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_10\day1_27-11-2024\BACK_CAM_seq006_27-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5, not copied.
# Found port tracking file BACK_CAM_seq006_27-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_10\day1_27-11-2024\BACK_CAM_seq006_27-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5, not copied.
# -------------------------------
# behav 2 =  SEQ006_1_10 28/11/2024
# path = Z:\projects\sequence_squad\revision_data\organised_data\animals\\seq006_implant1\recording11_28-11-2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_10\day2_28-11-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found task tracking file BACK_CAM_seq006_28-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_10\day2_28-11-2024\BACK_CAM_seq006_28-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5, not copied.
# Found port tracking file BACK_CAM_seq006_28-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_10\day2_28-11-2024\BACK_CAM_seq006_28-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5, not copied.
# -------------------------------
# behav 1 =  SEQ006_1_11 28/11/2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_11\day1_28-11-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found task tracking file BACK_CAM_seq006_28-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_11\day1_28-11-2024\BACK_CAM_seq006_28-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5, not copied.
# Found port tracking file BACK_CAM_seq006_28-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_11\day1_28-11-2024\BACK_CAM_seq006_28-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5, not copied.
# NOPE! bpod data (and camera data?) needs to be processed!
# -------------------------------
# behav 1 =  SEQ008_1_3 13/11/2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ008_1_3\day1_13-11-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found task tracking file BACK_CAM_seq008_13-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ008_1_3\day1_13-11-2024\BACK_CAM_seq008_13-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5, not copied.
# Found port tracking file BACK_CAM_seq008_13-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ008_1_3\day1_13-11-2024\BACK_CAM_seq008_13-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5, not copied.
# NOPE! bpod data (and camera data?) needs to be processed!
# -------------------------------
# behav 1 =  SEQ007_1_4 29/11/2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ007_1_4\day1_29-11-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found task tracking file BACK_CAM_seq007_29-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ007_1_4\day1_29-11-2024\BACK_CAM_seq007_29-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5, not copied.
# Found port tracking file BACK_CAM_seq007_29-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ007_1_4\day1_29-11-2024\BACK_CAM_seq007_29-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5, not copied.
# NOPE! bpod data (and camera data?) needs to be processed!
# -------------------------------
# behav 1 =  EJT268_1_2 02/05/2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT268_1_2\day1_02-05-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found port tracking file back_2023-05-02T12_20_10DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT268_1_2\day1_02-05-2024\back_2023-05-02T12_20_10DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5, not copied.
# Found task tracking file back_2023-05-02T12_20_10DLC_resnet50_Yellow-floor-task-tracking-backviewApr9shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT268_1_2\day1_02-05-2024\back_2023-05-02T12_20_10DLC_resnet50_Yellow-floor-task-tracking-backviewApr9shuffle1_800000.h5, not copied.
# NOPE! bpod data (and camera data?) needs to be processed!
# -------------------------------
# behav 1 =  EJT269_1_2 15/05/2023
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT269_1_2\day1_15-05-2023\Behav_Ephys_Camera_Sync.csv, not copied.
# Found port tracking file back_2023-05-15T15_02_57DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT269_1_2\day1_15-05-2023\back_2023-05-15T15_02_57DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5, not copied.
# Found task tracking file back_2023-05-15T15_02_57DLC_resnet50_Yellow-floor-task-tracking-backviewApr9shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT269_1_2\day1_15-05-2023\back_2023-05-15T15_02_57DLC_resnet50_Yellow-floor-task-tracking-backviewApr9shuffle1_800000.h5, not copied.
# -------------------------------
# behav 2 =  EJT269_1_2 16/05/2023
# path = Z:\projects\sequence_squad\organised_data\animals\\EJT269_implant1\recording3_16-05-2023
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT269_1_2\day2_16-05-2023\Behav_Ephys_Camera_Sync.csv, not copied.
# Found port tracking file back_2023-05-16T18_06_14DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT269_1_2\day2_16-05-2023\back_2023-05-16T18_06_14DLC_resnet50_port-tracking_back_viewMay2shuffle1_500000.h5, not copied.
# Found task tracking file back_2023-05-16T18_06_14DLC_resnet50_Yellow-floor-task-tracking-backviewApr9shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\EJT269_1_2\day2_16-05-2023\back_2023-05-16T18_06_14DLC_resnet50_Yellow-floor-task-tracking-backviewApr9shuffle1_800000.h5, not copied.
# -------------------------------
# behav 1 =  AP5R_1_1 16/11/2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\AP5R_1_1\day1_16-11-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found task tracking file BACK_CAM_AP5_2_R_16-11-2024DLC_resnet50_BACK_ap5_rigDec4shuffle1_720000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\AP5R_1_1\day1_16-11-2024\BACK_CAM_AP5_2_R_16-11-2024DLC_resnet50_BACK_ap5_rigDec4shuffle1_720000.h5, not copied.
# Found port tracking file BACK_CAM_AP5_2_R_16-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\AP5R_1_1\day1_16-11-2024\BACK_CAM_AP5_2_R_16-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5, not copied.
# NOPE! bpod data (and camera data?) needs to be processed!
# -------------------------------
# behav 1 =  AP5R_1_2 18/11/2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\AP5R_1_2\day1_18-11-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found task tracking file BACK_CAM_AP5_2_R_18-11-2024DLC_resnet50_BACK_ap5_rigDec4shuffle1_720000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\AP5R_1_2\day1_18-11-2024\BACK_CAM_AP5_2_R_18-11-2024DLC_resnet50_BACK_ap5_rigDec4shuffle1_720000.h5, not copied.
# Found port tracking file BACK_CAM_AP5_2_R_18-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\AP5R_1_2\day1_18-11-2024\BACK_CAM_AP5_2_R_18-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5, not copied.
# -------------------------------
# behav 2 =  AP5R_1_2 19/11/2024
# path = Z:\projects\sequence_squad\revision_data\organised_data\animals\\ap5R_implant1\recording3_19-11-2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\AP5R_1_2\day2_19-11-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found task tracking file BACK_CAM_AP5_2_R_19-11-2024DLC_resnet50_BACK_ap5_rigDec4shuffle1_720000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\AP5R_1_2\day2_19-11-2024\BACK_CAM_AP5_2_R_19-11-2024DLC_resnet50_BACK_ap5_rigDec4shuffle1_720000.h5, not copied.
# Found port tracking file BACK_CAM_AP5_2_R_19-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\AP5R_1_2\day2_19-11-2024\BACK_CAM_AP5_2_R_19-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5, not copied.
# -------------------------------
# behav 1 =  AP5R_1_3 19/11/2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\AP5R_1_3\day1_19-11-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found task tracking file BACK_CAM_AP5_2_R_19-11-2024DLC_resnet50_BACK_ap5_rigDec4shuffle1_720000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\AP5R_1_3\day1_19-11-2024\BACK_CAM_AP5_2_R_19-11-2024DLC_resnet50_BACK_ap5_rigDec4shuffle1_720000.h5, not copied.
# Found port tracking file BACK_CAM_AP5_2_R_19-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\AP5R_1_3\day1_19-11-2024\BACK_CAM_AP5_2_R_19-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5, not copied.
# -------------------------------
# behav 2 =  AP5R_1_3 20/11/2024
# path = Z:\projects\sequence_squad\revision_data\organised_data\animals\\ap5R_implant1\recording4_20-11-2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\AP5R_1_3\day2_20-11-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found task tracking file BACK_CAM_AP5_2_R_20-11-2024DLC_resnet50_BACK_ap5_rigDec4shuffle1_720000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\AP5R_1_3\day2_20-11-2024\BACK_CAM_AP5_2_R_20-11-2024DLC_resnet50_BACK_ap5_rigDec4shuffle1_720000.h5, not copied.
# Found port tracking file BACK_CAM_AP5_2_R_20-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\AP5R_1_3\day2_20-11-2024\BACK_CAM_AP5_2_R_20-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5, not copied.
# -------------------------------
# behav 1 =  SEQ006_1_1 15/11/2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_1\day1_15-11-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found task tracking file BACK_CAM_seq006_15-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_1\day1_15-11-2024\BACK_CAM_seq006_15-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5, not copied.
# Found port tracking file BACK_CAM_seq006_15-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_1\day1_15-11-2024\BACK_CAM_seq006_15-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5, not copied.
# -------------------------------
# behav 2 =  SEQ006_1_1 16/11/2024
# path = Z:\projects\sequence_squad\revision_data\organised_data\animals\\seq006_implant1\recording2_16-11-2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_1\day2_16-11-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found task tracking file BACK_CAM_seq006_16-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_1\day2_16-11-2024\BACK_CAM_seq006_16-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5, not copied.
# Found port tracking file BACK_CAM_seq006_16-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_1\day2_16-11-2024\BACK_CAM_seq006_16-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5, not copied.
# -------------------------------
# behav 1 =  SEQ006_1_2 16/11/2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_2\day1_16-11-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found task tracking file BACK_CAM_seq006_16-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_2\day1_16-11-2024\BACK_CAM_seq006_16-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5, not copied.
# Found port tracking file BACK_CAM_seq006_16-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_2\day1_16-11-2024\BACK_CAM_seq006_16-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5, not copied.
# NOPE! bpod data (and camera data?) needs to be processed!
# -------------------------------
# behav 1 =  SEQ006_1_3 18/11/2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_3\day1_18-11-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found task tracking file BACK_CAM_seq006_18-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_3\day1_18-11-2024\BACK_CAM_seq006_18-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5, not copied.
# Found port tracking file BACK_CAM_seq006_18-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_3\day1_18-11-2024\BACK_CAM_seq006_18-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5, not copied.
# -------------------------------
# behav 2 =  SEQ006_1_3 19/11/2024
# path = Z:\projects\sequence_squad\revision_data\organised_data\animals\\seq006_implant1\recording4_19-11-2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_3\day2_19-11-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found task tracking file BACK_CAM_seq006_19-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_3\day2_19-11-2024\BACK_CAM_seq006_19-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5, not copied.
# Found port tracking file BACK_CAM_seq006_19-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_3\day2_19-11-2024\BACK_CAM_seq006_19-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5, not copied.
# -------------------------------
# behav 1 =  SEQ006_1_4 19/11/2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_4\day1_19-11-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found task tracking file BACK_CAM_seq006_19-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_4\day1_19-11-2024\BACK_CAM_seq006_19-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5, not copied.
# Found port tracking file BACK_CAM_seq006_19-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_4\day1_19-11-2024\BACK_CAM_seq006_19-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5, not copied.
# -------------------------------
# behav 2 =  SEQ006_1_4 20/11/2024
# path = Z:\projects\sequence_squad\revision_data\organised_data\animals\\seq006_implant1\recording5_20-11-2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_4\day2_20-11-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found task tracking file BACK_CAM_seq006_20-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_4\day2_20-11-2024\BACK_CAM_seq006_20-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5, not copied.
# Found port tracking file BACK_CAM_seq006_20-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_4\day2_20-11-2024\BACK_CAM_seq006_20-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5, not copied.
# -------------------------------
# behav 1 =  SEQ006_1_5 20/11/2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_5\day1_20-11-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found task tracking file BACK_CAM_seq006_20-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_5\day1_20-11-2024\BACK_CAM_seq006_20-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5, not copied.
# Found port tracking file BACK_CAM_seq006_20-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_5\day1_20-11-2024\BACK_CAM_seq006_20-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5, not copied.
# -------------------------------
# behav 2 =  SEQ006_1_5 21/11/2024
# path = Z:\projects\sequence_squad\revision_data\organised_data\animals\\seq006_implant1\recording6_21-11-2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_5\day2_21-11-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found task tracking file BACK_CAM_seq006_21-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_5\day2_21-11-2024\BACK_CAM_seq006_21-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5, not copied.
# Found port tracking file BACK_CAM_seq006_21-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_5\day2_21-11-2024\BACK_CAM_seq006_21-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5, not copied.
# -------------------------------
# behav 1 =  SEQ006_1_6 21/11/2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_6\day1_21-11-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found task tracking file BACK_CAM_seq006_21-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_6\day1_21-11-2024\BACK_CAM_seq006_21-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5, not copied.
# Found port tracking file BACK_CAM_seq006_21-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_6\day1_21-11-2024\BACK_CAM_seq006_21-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5, not copied.
# -------------------------------
# behav 2 =  SEQ006_1_6 22/11/2024
# path = Z:\projects\sequence_squad\revision_data\organised_data\animals\\seq006_implant1\recording7_22-11-2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_6\day2_22-11-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found task tracking file BACK_CAM_seq006_22-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_6\day2_22-11-2024\BACK_CAM_seq006_22-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5, not copied.
# Found port tracking file BACK_CAM_seq006_22-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_6\day2_22-11-2024\BACK_CAM_seq006_22-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5, not copied.
# -------------------------------
# behav 1 =  SEQ006_1_7 22/11/2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_7\day1_22-11-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found task tracking file BACK_CAM_seq006_22-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_7\day1_22-11-2024\BACK_CAM_seq006_22-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5, not copied.
# Found port tracking file BACK_CAM_seq006_22-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ006_1_7\day1_22-11-2024\BACK_CAM_seq006_22-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5, not copied.
# NOPE! bpod data (and camera data?) needs to be processed!
# -------------------------------
# behav 1 =  SEQ007_1_1 18/11/2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ007_1_1\day1_18-11-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found task tracking file BACK_CAM_seq007_18-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ007_1_1\day1_18-11-2024\BACK_CAM_seq007_18-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5, not copied.
# Found port tracking file BACK_CAM_seq007_18-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ007_1_1\day1_18-11-2024\BACK_CAM_seq007_18-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5, not copied.
# -------------------------------
# behav 2 =  SEQ007_1_1 19/11/2024
# path = Z:\projects\sequence_squad\revision_data\organised_data\animals\\seq007_implant1\recording2_19-11-2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ007_1_1\day2_19-11-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found task tracking file BACK_CAM_seq007_19-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ007_1_1\day2_19-11-2024\BACK_CAM_seq007_19-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5, not copied.
# Found port tracking file BACK_CAM_seq007_19-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ007_1_1\day2_19-11-2024\BACK_CAM_seq007_19-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5, not copied.
# -------------------------------
# behav 1 =  SEQ007_1_2 19/11/2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ007_1_2\day1_19-11-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found task tracking file BACK_CAM_seq007_19-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ007_1_2\day1_19-11-2024\BACK_CAM_seq007_19-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5, not copied.
# Found port tracking file BACK_CAM_seq007_19-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ007_1_2\day1_19-11-2024\BACK_CAM_seq007_19-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5, not copied.
# -------------------------------
# behav 2 =  SEQ007_1_2 20/11/2024
# path = Z:\projects\sequence_squad\revision_data\organised_data\animals\\seq007_implant1\recording3_20-11-2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ007_1_2\day2_20-11-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found task tracking file BACK_CAM_seq007_20-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ007_1_2\day2_20-11-2024\BACK_CAM_seq007_20-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5, not copied.
# Found port tracking file BACK_CAM_seq007_20-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ007_1_2\day2_20-11-2024\BACK_CAM_seq007_20-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5, not copied.
# -------------------------------
# behav 1 =  SEQ007_1_3 20/11/2024
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ007_1_3\day1_20-11-2024\Behav_Ephys_Camera_Sync.csv, not copied.
# Found task tracking file BACK_CAM_seq007_20-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ007_1_3\day1_20-11-2024\BACK_CAM_seq007_20-11-2024DLC_resnet50_BACK_hippocampusDec10shuffle1_800000.h5, not copied.
# Found port tracking file BACK_CAM_seq007_20-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5
# File already exists at Z:\projects\sequence_squad\revision_data\emmett_revisions\sleep_wake_link_data\replay_to_behaviour\\SEQ007_1_3\day1_20-11-2024\BACK_CAM_seq007_20-11-2024DLC_resnet50_BACK_PORTS_hpc_rigDec4shuffle1_640000.h5, not copied.
# NOPE! bpod data (and camera data?) needs to be processed!

# %%
# find the behavioural data from the day of the recording and the day after

# if both recordings have tracking data then extract this also

# extract the features of behaviour as i did before

C:\Users\Emmett Thompson\Documents\sequences_analyse_PPseq\revision_analysis\prioritisation_analysis\sleep_behaviour_link\consecutive_data.csv
